# %%
# Test if the class Instance is correctly implemented
from src.instance import Instance

instance = Instance.from_csv("data/instance1.csv")
print(instance)
# Out:
# Instance(n=5, f=[7, 2, 2, 7, 7], c=[99, 5, 4, 3, 2], d=2)

# %%
# test the resolution of an instance with the no decomposition model
import gurobipy as gp
from src.base import no_decomposition_model
solution = no_decomposition_model(instance)
solution.optimize()
print(f"Optimal value: {solution.objVal}")
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 6 rows, 10 columns and 15 nonzeros
# Model fingerprint: 0xeed2d3df
# Variable types: 5 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Presolve removed 6 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Optimal value: 13.0

# %%
extended_instance = instance.extend_instance(100000)
print(extended_instance)
# Out:
# Instance(n=100000, f=[7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 10, 70, 13, 91, 1, 7, 49, 25, 16, 112, 148, 82, 97, 43, 142, 40, 121, 52, 46, 4, 28, 37, 100, 64, 130, 115, 1 ...

# %%
model2 = no_decomposition_model(extended_instance)
model2.optimize()
print(f"Optimal value: {model2.objVal}")
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 100001 rows, 200000 columns and 300000 nonzeros
# Model fingerprint: 0x0c6d29b1
# Variable types: 100000 continuous, 100000 integer (100000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+04, 5e+04]
# Found heuristic solution: objective 4661803.0000
# Presolve removed 100000 rows and 100000 columns
# Presolve time: 0.04s
# Presolved: 1 rows, 100000 columns, 100000 nonzeros
# Variable types: 0 continuous, 100000 integer (100000 binary)
# Performing another presolve...
# Presolve removed 0 rows and 99792 columns
# Presolve time: 0.09s
# Performing another presolve...
# Presolve time: 0.00s
#
# Root relaxation: objective 2.613424e+06, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2613424.0000 2613424.00  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.25 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 2.61342e+06 4.6618e+06 4.6618e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.613424000000e+06, best bound 2.613424000000e+06, gap 0.0000%
# Optimal value: 2613424.0

# %%
from src.Ex1 import solve_benders

Instance = Instance.from_csv('data/instance1.csv')
print(Instance)
obj, y = solve_benders(Instance)
#print(f"Optimal value: {obj}")
# Out:
# Instance(n=5, f=[7, 2, 2, 7, 7], c=[99, 5, 4, 3, 2], d=2)
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1 rows, 3 columns and 1 nonzeros
# Model fingerprint: 0x5ea70cf0
# Variable types: 1 continuous, 2 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Solving separation problem with d=2, y=[-0.0, -0.0], c=[99, 5, 4, 3, 2]
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4 rows, 3 columns and 6 nonzeros
# Model fingerprint: 0x342fb968
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 1e+02]
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# Set parameter OutputFlag to value 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3 Instance = Instance.from_csv('data/instance1.csv')
#       4 print(Instance)
# ----> 5 obj, y = solve_benders(Instance)
#       6 #print(f"Optimal value: {obj}")
#
# File c:\Users\Erwann\Documents\MPRO\MLA\MLA_TP\src\Ex1.py:82, in solve_benders(instance)
#      80 cuts = [(0, np.zeros(d))]
#      81 while True:
# ---> 82     obj_master, y_vals, w_val = solve_master(c, f, n, d, cuts)
#      83     obj_sep, b_val, v_vals = solve_separation(d, y_vals, c)
#      84     if obj_sep <= w_val + 1e-6:  # Tolérance pour la convergence
#
# File c:\Users\Erwann\Documents\MPRO\MLA\MLA_TP\src\Ex1.py:64, in solve_master(c, f, n, d, cuts)
#      61     m.setObjective(gurobipy.quicksum((f[i]*y[i]) for i in range(d)) + w, gurobipy.GRB.MINIMIZE)
#      63     # Constraints
# ---> 64     m.addConstrs( w >= cuts[j][0]*d -  gurobipy.quicksum((cuts[j][1][i]*y[i]) for i in range(d)) for j in range(len(cuts)))
#      65 #    for (b_val, v_vals) in cuts:
#      66 #        m.addConstr(w >= d * b_val - gurobipy.quicksum(v_vals[i] * y[i] for i in range(d)))
#      67     m.optimize()
#
# File src\\gurobipy\\_model.pyx:4087, in gurobipy._model.Model.addConstrs()
#
# File c:\Users\Erwann\Documents\MPRO\MLA\MLA_TP\src\Ex1.py:64, in <genexpr>(.0)
#      61     m.setObjective(gurobipy.quicksum((f[i]*y[i]) for i in range(d)) + w, gurobipy.GRB.MINIMIZE)
#      63     # Constraints
# ---> 64     m.addConstrs( w >= cuts[j][0]*d -  gurobipy.quicksum((cuts[j][1][i]*y[i]) for i in range(d)) for j in range(len(cuts)))
#      65 #    for (b_val, v_vals) in cuts:
#      66 #        m.addConstr(w >= d * b_val - gurobipy.quicksum(v_vals[i] * y[i] for i in range(d)))
#      67     m.optimize()
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
