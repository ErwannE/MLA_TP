# %%
# Test if the class Instance is correctly implemented
from src.instance import Instance

instance = Instance.from_csv("data/instance1.csv")
print(instance)
# Out:
# Instance(n=5, f=[7, 2, 2, 7, 7], c=[99, 5, 4, 3, 2], d=2)

# %%
# test the resolution of an instance with the no decomposition model
import gurobipy as gp
from src.base import no_decomposition_model
solution = no_decomposition_model(instance)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # test the resolution of an instance with the no decomposition model
#       2 import gurobipy as gp
# ----> 3 from src.base import no_decomposition_model
#       4 solution = no_decomposition_model(instance)
#
# File c:\Users\Erwann\Documents\MPRO\MLA\MLA_TP\src\base.py:1
# ----> 1 from instance import Instance
#       2 import gurobipy as gp
#       3 from gurobipy import GRB
#
# ModuleNotFoundError: No module named 'instance'
